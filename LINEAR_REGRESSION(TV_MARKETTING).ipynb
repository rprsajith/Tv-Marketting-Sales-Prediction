# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/tvmarketing.csv')

# %%
data.head(10)
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# 5    8.7    7.2
# 6   57.5   11.8
# 7  120.2   13.2
# 8    8.6    4.8
# 9  199.8   10.6

# %%
data.tail(10)
# Out:
#         TV  Sales
# 190   39.5   10.8
# 191   75.5    9.9
# 192   17.2    5.9
# 193  166.8   19.6
# 194  149.7   17.3
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
data.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
(data.describe().T)
# Out:
#        count      mean        std  min     25%     50%      75%    max
# TV     200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Sales  200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
data.shape
# Out:
# (200, 2)

# %%
data.isnull()
# Out:
#         TV  Sales
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 195  False  False
# 196  False  False
# 197  False  False
# 198  False  False
# 199  False  False
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = data['Sales']
plt.plot(x)

# %%
x = data['TV']
y = data['Sales']
plt.bar(x,y)
# Out:
# <BarContainer object of 200 artists>

# %%
x = data['TV']
y = data['Sales']
plt.scatter(x,y)

# %%
plt.pie(x=data['TV'])
# Out:
# ([<matplotlib.patches.Wedge at 0x79eefde09b40>,
#   <matplotlib.patches.Wedge at 0x79eefde09a50>,
#   <matplotlib.patches.Wedge at 0x79eefde0a410>,
#   <matplotlib.patches.Wedge at 0x79eefde0a770>,
#   <matplotlib.patches.Wedge at 0x79eefde0abf0>,
#   <matplotlib.patches.Wedge at 0x79eefde0b070>,
#   <matplotlib.patches.Wedge at 0x79eefde0b4f0>,
#   <matplotlib.patches.Wedge at 0x79eefde0b970>,
#   <matplotlib.patches.Wedge at 0x79eefde0bdf0>,
#   <matplotlib.patches.Wedge at 0x79eefde482b0>,
#   <matplotlib.patches.Wedge at 0x79eefde09b10>,
#   <matplotlib.patches.Wedge at 0x79eefde48b80>,
#   <matplotlib.patches.Wedge at 0x79eefde49000>,
#   <matplotlib.patches.Wedge at 0x79eefde49480>,
#   <matplotlib.patches.Wedge at 0x79eefde49900>,
#   <matplotlib.patches.Wedge at 0x79eefde49d80>,
#   <matplotlib.patches.Wedge at 0x79eefde4a200>,
#   <matplotlib.patches.Wedge at 0x79eefde4a680>,
#   <matplotlib.patches.Wedge at 0x79eefde4ab00>,
#   <matplotlib.patches.Wedge at 0x79eefde4af80>,
#   <matplotlib.patches.Wedge at 0x79eefde4b400>,
#   <matplotlib.patches.Wedge at 0x79eefde4b8b0>,
#   <matplotlib.patches.Wedge at 0x79eefde4bd30>,
#   <matplotlib.patches.Wedge at 0x79eefdc801f0>,
#   <matplotlib.patches.Wedge at 0x79eefdc80670>,
#   <matplotlib.patches.Wedge at 0x79eefdc80af0>,
#   <matplotlib.patches.Wedge at 0x79eefdc80f70>,
#   <matplotlib.patches.Wedge at 0x79eefdc813f0>,
#   <matplotlib.patches.Wedge at 0x79eefdc81870>,
#   <matplotlib.patches.Wedge at 0x79eefdc81cf0>,
#   <matplotlib.patches.Wedge at 0x79eefddd0310>,
#   <matplotlib.patches.Wedge at 0x79eefdc820e0>,
#   <matplotlib.patches.Wedge at 0x79eefdc82560>,
#   <matplotlib.patches.Wedge at 0x79eefdc829e0>,
#   <matplotlib.patches.Wedge at 0x79eefdc82e60>,
#   <matplotlib.patches.Wedge at 0x79eefdc832e0>,
#   <matplotlib.patches.Wedge at 0x79eefdc83760>,
#   <matplotlib.patches.Wedge at 0x79eefdc83be0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc00a0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc0520>,
#   <matplotlib.patches.Wedge at 0x79eefdcc09a0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc0e20>,
#   <matplotlib.patches.Wedge at 0x79eefdcc12a0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc1720>,
#   <matplotlib.patches.Wedge at 0x79eefdcc1ba0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc2020>,
#   <matplotlib.patches.Wedge at 0x79eefdcc24a0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc2920>,
#   <matplotlib.patches.Wedge at 0x79eefdcc2da0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc3220>,
#   <matplotlib.patches.Wedge at 0x79eefdcc36a0>,
#   <matplotlib.patches.Wedge at 0x79eefdcc3b20>,
#   <matplotlib.patches.Wedge at 0x79eefdcc3fa0>,
#   <matplotlib.patches.Wedge at 0x79eefdcf8460>,
#   <matplotlib.patches.Wedge at 0x79eefdcf88e0>,
#   <matplotlib.patches.Wedge at 0x79eefdcf8d60>,
#   <matplotlib.patches.Wedge at 0x79eefdcf91e0>,
#   <matplotlib.patches.Wedge at 0x79eefdcf9660>,
#   <matplotlib.patches.Wedge at 0x79eefdcf9ae0>,
#   <matplotlib.patches.Wedge at 0x79eefdcf9f60>,
#   <matplotlib.patches.Wedge at 0x79eefdcfa3e0>,
#   <matplotlib.patches.Wedge at 0x79eefdcfa860>,
#   <matplotlib.patches.Wedge at 0x79eefdcface0>,
#   <matplotlib.patches.Wedge at 0x79eefdcfb160>,
#   <matplotlib.patches.Wedge at 0x79eefdcfb5e0>,
#   <matplotlib.patches.Wedge at 0x79eefdcfba60>,
#   <matplotlib.patches.Wedge at 0x79eefdcfbee0>,
#   <matplotlib.patches.Wedge at 0x79eefdd383a0>,
#   <matplotlib.patches.Wedge at 0x79eefdd38820>,
#   <matplotlib.patches.Wedge at 0x79eefdd38ca0>,
#   <matplotlib.patches.Wedge at 0x79eefdd39120>,
#   <matplotlib.patches.Wedge at 0x79eefdd395a0>,
#   <matplotlib.patches.Wedge at 0x79eefdd39a20>,
#   <matplotlib.patches.Wedge at 0x79eefdd39ea0>,
#   <matplotlib.patches.Wedge at 0x79eefdd3a320>,
#   <matplotlib.patches.Wedge at 0x79eefdd3a7a0>,
#   <matplotlib.patches.Wedge at 0x79eefdd3ac20>,
#   <matplotlib.patches.Wedge at 0x79eefdd3b0a0>,
#   <matplotlib.patches.Wedge at 0x79eefdd3b520>,
#   <matplotlib.patches.Wedge at 0x79eefdd3b9a0>,
#   <matplotlib.patches.Wedge at 0x79eefdd3be20>,
#   <matplotlib.patches.Wedge at 0x79eefdb782e0>,
#   <matplotlib.patches.Wedge at 0x79eefdb78760>,
#   <matplotlib.patches.Wedge at 0x79eefdb78be0>,
#   <matplotlib.patches.Wedge at 0x79eefdb79060>,
#   <matplotlib.patches.Wedge at 0x79eefdb794e0>,
#   <matplotlib.patches.Wedge at 0x79eefdb79960>,
#   <matplotlib.patches.Wedge at 0x79eefdb79de0>,
#   <matplotlib.patches.Wedge at 0x79eefdb7a260>,
#   <matplotlib.patches.Wedge at 0x79eefdb7a6e0>,
#   <matplotlib.patches.Wedge at 0x79eefdb7ab60>,
#   <matplotlib.patches.Wedge at 0x79eefdb7afe0>,
#   <matplotlib.patches.Wedge at 0x79eefdb7b460>,
#   <matplotlib.patches.Wedge at 0x79eefdb7b8e0>,
#   <matplotlib.patches.Wedge at 0x79eefdb7bd60>,
#   <matplotlib.patches.Wedge at 0x79eefdbb4220>,
#   <matplotlib.patches.Wedge at 0x79eefdbb46a0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb4b20>,
#   <matplotlib.patches.Wedge at 0x79eefdbb4fa0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb5420>,
#   <matplotlib.patches.Wedge at 0x79eefdbb58a0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb5d20>,
#   <matplotlib.patches.Wedge at 0x79eefdbb61a0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb6620>,
#   <matplotlib.patches.Wedge at 0x79eefdbb6aa0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb6f20>,
#   <matplotlib.patches.Wedge at 0x79eefdbb73a0>,
#   <matplotlib.patches.Wedge at 0x79eefdbb7820>,
#   <matplotlib.patches.Wedge at 0x79eefdbb7ca0>,
#   <matplotlib.patches.Wedge at 0x79eefdbec160>,
#   <matplotlib.patches.Wedge at 0x79eefdbec5e0>,
#   <matplotlib.patches.Wedge at 0x79eefdbeca60>,
#   <matplotlib.patches.Wedge at 0x79eefdbecee0>,
#   <matplotlib.patches.Wedge at 0x79eefdbed360>,
#   <matplotlib.patches.Wedge at 0x79eefdbed7e0>,
#   <matplotlib.patches.Wedge at 0x79eefdbedd50>,
#   <matplotlib.patches.Wedge at 0x79eefdbee110>,
#   <matplotlib.patches.Wedge at 0x79eefdbee590>,
#   <matplotlib.patches.Wedge at 0x79eefdbeea10>,
#   <matplotlib.patches.Wedge at 0x79eefdbeee90>,
#   <matplotlib.patches.Wedge at 0x79eefdbef310>,
#   <matplotlib.patches.Wedge at 0x79eefdbef790>,
#   <matplotlib.patches.Wedge at 0x79eefdbefc10>,
#   <matplotlib.patches.Wedge at 0x79eefdc300d0>,
#   <matplotlib.patches.Wedge at 0x79eefdc30550>,
#   <matplotlib.patches.Wedge at 0x79eefdc309d0>,
#   <matplotlib.patches.Wedge at 0x79eefdc30e50>,
#   <matplotlib.patches.Wedge at 0x79eefdc312d0>,
#   <matplotlib.patches.Wedge at 0x79eefdc31750>,
#   <matplotlib.patches.Wedge at 0x79eefdc31bd0>,
#   <matplotlib.patches.Wedge at 0x79eefdc32050>,
#   <matplotlib.patches.Wedge at 0x79eefdc324d0>,
#   <matplotlib.patches.Wedge at 0x79eefdc32950>,
#   <matplotlib.patches.Wedge at 0x79eefdc32dd0>,
#   <matplotlib.patches.Wedge at 0x79eefdc33250>,
#   <matplotlib.patches.Wedge at 0x79eefdc336d0>,
#   <matplotlib.patches.Wedge at 0x79eefdc33b50>,
#   <matplotlib.patches.Wedge at 0x79eefdc33fd0>,
#   <matplotlib.patches.Wedge at 0x79eefdc68490>,
#   <matplotlib.patches.Wedge at 0x79eefdc68910>,
#   <matplotlib.patches.Wedge at 0x79eefdc68d90>,
#   <matplotlib.patches.Wedge at 0x79eefdc69210>,
#   <matplotlib.patches.Wedge at 0x79eefdc69690>,
#   <matplotlib.patches.Wedge at 0x79eefdc69b10>,
#   <matplotlib.patches.Wedge at 0x79eefdc69f90>,
#   <matplotlib.patches.Wedge at 0x79eefdc6a410>,
#   <matplotlib.patches.Wedge at 0x79eefdc6a890>,
#   <matplotlib.patches.Wedge at 0x79eefdc6ad10>,
#   <matplotlib.patches.Wedge at 0x79eefdc6b190>,
#   <matplotlib.patches.Wedge at 0x79eefdc6b610>,
#   <matplotlib.patches.Wedge at 0x79eefdc6ba90>,
#   <matplotlib.patches.Wedge at 0x79eefdc6bf10>,
#   <matplotlib.patches.Wedge at 0x79eefdaa43d0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa4850>,
#   <matplotlib.patches.Wedge at 0x79eefdaa4cd0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa5150>,
#   <matplotlib.patches.Wedge at 0x79eefdaa55d0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa5a50>,
#   <matplotlib.patches.Wedge at 0x79eefdaa5ed0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa6350>,
#   <matplotlib.patches.Wedge at 0x79eefdaa67d0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa6c50>,
#   <matplotlib.patches.Wedge at 0x79eefdaa70d0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa7550>,
#   <matplotlib.patches.Wedge at 0x79eefdaa79d0>,
#   <matplotlib.patches.Wedge at 0x79eefdaa7e50>,
#   <matplotlib.patches.Wedge at 0x79eefdae0310>,
#   <matplotlib.patches.Wedge at 0x79eefdae0790>,
#   <matplotlib.patches.Wedge at 0x79eefdae0c10>,
#   <matplotlib.patches.Wedge at 0x79eefdae1090>,
#   <matplotlib.patches.Wedge at 0x79eefdae1510>,
#   <matplotlib.patches.Wedge at 0x79eefdae1990>,
#   <matplotlib.patches.Wedge at 0x79eefdae1e10>,
#   <matplotlib.patches.Wedge at 0x79eefdae2290>,
#   <matplotlib.patches.Wedge at 0x79eefdae2710>,
#   <matplotlib.patches.Wedge at 0x79eefdae2bc0>,
#   <matplotlib.patches.Wedge at 0x79eefdae3040>,
#   <matplotlib.patches.Wedge at 0x79eefdae34c0>,
#   <matplotlib.patches.Wedge at 0x79eefdae3940>,
#   <matplotlib.patches.Wedge at 0x79eefdae3dc0>,
#   <matplotlib.patches.Wedge at 0x79eefdb1c280>,
#   <matplotlib.patches.Wedge at 0x79eefdb1c700>,
#   <matplotlib.patches.Wedge at 0x79eefdb1cb80>,
#   <matplotlib.patches.Wedge at 0x79eefdb1d000>,
#   <matplotlib.patches.Wedge at 0x79eefdb1d480>,
#   <matplotlib.patches.Wedge at 0x79eefdb1d900>,
#   <matplotlib.patches.Wedge at 0x79eefdb1dd80>,
#   <matplotlib.patches.Wedge at 0x79eefdb1e200>,
#   <matplotlib.patches.Wedge at 0x79eefdb1e680>,
#   <matplotlib.patches.Wedge at 0x79eefdb1eb00>,
#   <matplotlib.patches.Wedge at 0x79eefdb1ef80>,
#   <matplotlib.patches.Wedge at 0x79eefdb1f400>,
#   <matplotlib.patches.Wedge at 0x79eefdb1f880>,
#   <matplotlib.patches.Wedge at 0x79eefdb1fdf0>,
#   <matplotlib.patches.Wedge at 0x79eefdb601f0>,
#   <matplotlib.patches.Wedge at 0x79eefdb60670>,
#   <matplotlib.patches.Wedge at 0x79eefdb60af0>,
#   <matplotlib.patches.Wedge at 0x79eefdb60f70>,
#   <matplotlib.patches.Wedge at 0x79eefdb613f0>,
#   <matplotlib.patches.Wedge at 0x79eefdb61870>],
#  [Text(1.0996677016936736, 0.027036010278034827, ''),
#   Text(1.0984016269163994, 0.05927787097565927, ''),
#   Text(1.0979870604359523, 0.06651627706972639, ''),
#   Text(1.0966101039078515, 0.08629183047781094, ''),
#   Text(1.0928566734497622, 0.12515706650573044, ''),
#   Text(1.090099306910019, 0.14725318697500558, ''),
#   Text(1.0890306998458603, 0.15495849377570717, ''),
#   Text(1.0858930902461894, 0.17560238197581834, ''),
#   Text(1.0833742336293068, 0.19052629715635638, ''),
#   Text(1.0788645242236594, 0.21459575571678277, ''),
#   Text(1.0723345341028068, 0.24515025386590295, ''),
#   Text(1.0644995182749923, 0.27720168757117947, ''),
#   Text(1.057092257264478, 0.30423010967274555, ''),
#   Text(1.0530614087393286, 0.3179019808430595, ''),
#   Text(1.0422742682916948, 0.35165942281845974, ''),
#   Text(1.0263220412602805, 0.39580685646326447, ''),
#   Text(1.0147891129867666, 0.4245033052445315, ''),
#   Text(0.9982512780228152, 0.4620545270050021, ''),
#   Text(0.980249842391766, 0.4991094534177028, ''),
#   Text(-0.8043659445230325, 0.7503302121676628, ''),
#   Text(-0.8312975860705899, 0.7203779031822188, ''),
#   Text(-0.8487669938212596, 0.6997103616494629, ''),
#   Text(-0.852076212616467, 0.6956767409459492, ''),
#   Text(-0.8629680848528014, 0.6821188199467072, ''),
#   Text(-0.8720638447742287, 0.6704510799734684, ''),
#   Text(-0.8806851313543298, 0.6590855023526211, ''),
#   Text(-0.8940445645023388, 0.6408465625122939, ''),
#   Text(-0.9151772155144348, 0.6102873619887977, ''),
#   Text(-0.9351977197029644, 0.5791418004792747, ''),
#   Text(-0.9439775294395767, 0.564718003886146, ''),
#   Text(-0.9605530198493388, 0.5360390807192287, ''),
#   Text(-0.982928109486071, 0.4938140658002144, ''),
#   Text(-0.9967355418211222, 0.4653152261323008, ''),
#   Text(-1.005831404799254, 0.445312457853538, ''),
#   Text(-1.0150700429901798, 0.42383110766426163, ''),
#   Text(-1.0238113000629847, 0.40225666167677243, ''),
#   Text(-1.033951387759209, 0.3754257952655971, ''),
#   Text(-1.0403276509978157, 0.3573770817629008, ''),
#   Text(-1.0493695232582014, 0.32988422765699993, ''),
#   Text(-1.0645616748736013, 0.2769628863048496, ''),
#   Text(-1.0743803371964864, 0.23602307312117743, ''),
#   Text(-1.0807554661726693, 0.2048600066823601, ''),
#   Text(-1.0878484781903857, 0.16305118367820068, ''),
#   Text(-1.0936010314539164, 0.11847693447642123, ''),
#   Text(-1.0981999711615078, 0.06290328561262415, ''),
#   Text(-1.099923085650087, 0.013007907364051012, ''),
#   Text(-1.099617410162721, -0.029009503046942903, ''),
#   Text(-1.0963221692076028, -0.08987603297841035, ''),
#   Text(-1.088710581578207, -0.15719182408650312, ''),
#   Text(-1.0794925487610998, -0.21141390013257172, ''),
#   Text(-1.0687544860524454, -0.26031490265210244, ''),
#   Text(-1.0574360772923024, -0.3030329065310699, ''),
#   Text(-1.0520028715583718, -0.32138755145920034, ''),
#   Text(-1.0479610588726793, -0.3343316004903704, ''),
#   Text(-1.044200545673254, -0.3458977022411088, ''),
#   Text(-1.0338510943164452, -0.37570189616328686, ''),
#   Text(-1.0131811210479875, -0.42832699652478506, ''),
#   Text(-0.9905356306558406, -0.47837136661932045, ''),
#   Text(-0.9682279876083877, -0.5220484307148255, ''),
#   Text(-0.9459264623310033, -0.5614473509261161, ''),
#   Text(-0.9282207273116841, -0.5902595034296085, ''),
#   Text(-0.9184303522468431, -0.6053806142186419, ''),
#   Text(-0.9043320417281051, -0.6262456054168181, ''),
#   Text(-0.8896699788478034, -0.6469059659154097, ''),
#   Text(-0.8754973311576633, -0.665961277504788, ''),
#   Text(-0.8650698699259445, -0.6794513375851944, ''),
#   Text(-0.8532788766181365, -0.6942010938606271, ''),
#   Text(-0.8412818507256848, -0.7086923504875489, ''),
#   Text(-0.8226193381718468, -0.7302721578053711, ''),
#   Text(-0.7949821220984633, -0.7602653652138996, ''),
#   Text(-0.7657882011099525, -0.7896634922805936, ''),
#   Text(-0.7386393478960956, -0.8151146629399025, ''),
#   Text(0.880480917638536, -0.6593582893043824, ''),
#   Text(0.9061878492603832, -0.6235572001451359, ''),
#   Text(0.924093427068416, -0.5967003754389218, ''),
#   Text(0.9453802209891249, -0.5623666399801409, ''),
#   Text(0.9763062180762673, -0.5067801974679123, ''),
#   Text(0.9999620874912006, -0.4583402923377351, ''),
#   Text(1.0161488430492092, -0.4212380903595419, ''),
#   Text(1.0303888424380179, -0.3850958755676849, ''),
#   Text(1.0486694275163582, -0.3321030439374414, ''),
#   Text(1.058921953974679, -0.29779908561049645, ''),
#   Text(1.060752974528428, -0.2912097646527195, ''),
#   Text(1.0642503499315021, -0.27815677714317016, ''),
#   Text(1.0669526454111027, -0.2676042833182046, ''),
#   Text(1.0720062264400108, -0.24658193460561686, ''),
#   Text(1.0797290083866635, -0.21020292207377234, ''),
#   Text(1.0837305362658676, -0.1884890574142045, ''),
#   Text(1.0862879958106402, -0.173142687277583, ''),
#   Text(1.0908476019601947, -0.14160335200020122, ''),
#   Text(1.0964920245486265, -0.08777949704375258, ''),
#   Text(1.099661900640628, -0.027270942034362002, '')])

# %%
plt.hist(x=data['Sales'])
# Out:
# (array([ 2.,  9., 20., 47., 35., 29., 22., 17., 12.,  7.]),
#  array([ 1.6 ,  4.14,  6.68,  9.22, 11.76, 14.3 , 16.84, 19.38, 21.92,
#         24.46, 27.  ]),
#  <BarContainer object of 10 artists>)

# %%
x = data['TV']
sns.lineplot(x)
# Out:
# <Axes: ylabel='TV'>

# %%
x = data['Sales']
sns.countplot(x)
# Out:
# <Axes: ylabel='count'>

# %%
x = data['Sales']
sns.barplot(x)
# Out:
# <Axes: >

# %%
x = data['Sales']
sns.scatterplot(x)
# Out:
# <Axes: ylabel='Sales'>

# %%
sns.pairplot(data, hue='Sales')

# %%
sns.distplot(x=data['TV'])
# Out:
# <ipython-input-22-7ff20308ca5b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['TV'])
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=data['Sales'])
# Out:
# <Axes: xlabel='Sales'>

# %%
x = data.drop('Sales', axis=1)
print(x)
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y = data['Sales']
print(y)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.30, random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (140, 1)
# (60, 1)
# (140,)
# (60,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 7.310810165411681
# [0.04581434]

# %%
y_predict = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y_predict, y_test)
r_squared
# Out:
# 0.5341715753018943

# %%
lr.predict([[180.2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.56655462])

# %%
plt.scatter(x_train,y_train,color='r')
plt.plot(x_test,y_predict,color='k')
plt.show()
